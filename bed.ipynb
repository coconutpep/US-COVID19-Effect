# %%
#Import Dependencies
import pandas as pd
import requests
import json
from pprint import pprint

# %%
#Call API for GeoJSON data
request = requests.get("https://opendata.arcgis.com/datasets/1044bb19da8d4dbfb6a96eb1b4ebf629_0.geojson").json()
pprint(request)
# Out:
# t',
#                               'HQ_ADDRESS1': None,
#                               'HQ_CITY': 'Salisbury',
#                               'HQ_STATE': 'MD',
#                               'HQ_ZIP_CODE': '21801',
#                               'NUM_ICU_BEDS': 0,
#                               'NUM_LICENSED_BEDS': None,
#                               'NUM_STAFFED_BEDS': None,
#                               'PEDI_ICU_BEDS': None,
#                               'Potential_Increase_In_Bed_Capac': 0,
#                               'STATE_FIPS': '24',
#                               'STATE_NAME': 'Maryland'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-106.58138039999994, 35.057986],
#                             'type': 'Point'},
#                'properties': {'ADULT_ICU_BEDS': 0,
#                               'AVG_VENTILATOR_USAGE': None,
#                               'BED_UTILIZATION': None,
# ...
